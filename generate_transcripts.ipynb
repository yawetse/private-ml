# %% [markdown]
# ## Differentially Private Synthetic Call Transcript Generation
#
# This notebook generates differentially private synthetic call transcripts based on an input CSV file, using Microsoft's Private Evolution library and OpenAI's GPT models.
#
# **Prerequisites:**
# 1.  **Install Dependencies:**
#     ```bash
#     pip install "private-evolution[text] @ git+[https://github.com/microsoft/DPSDA.git](https://github.com/microsoft/DPSDA.git)"
#     pip install python-dotenv pandas
#     ```
# 2.  **OpenAI API Key:** Create a `.env` file in the same directory as this notebook with your OpenAI API key:
#     ```
#     OPENAI_API_KEY=your_actual_openai_api_key
#     ```
# 3.  **Input Data:** Place your input CSV file (e.g., `call_transcripts.csv`) in the same directory or update the `input_csv_path` variable below.
# 4.  **Run Cells:** Execute the cells sequentially.

# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
import os
import numpy as np
import json
import logging # Import standard logging
from dotenv import load_dotenv

# Import necessary PE components
from pe.data.text import TextCSV # To load data from CSV
from pe.logging import setup_logging # For setting up logging
from pe.runner import PE # The main PE runner class
from pe.population import PEPopulation # Default population strategy
from pe.api.text import LLMAugPE # API for text generation using LLMs
from pe.llm import OpenAILLM # OpenAI LLM wrapper
from pe.embedding.text import SentenceTransformer # Sentence embedding model
from pe.histogram import NearestNeighbors # Histogram based on nearest neighbors
from pe.callback import SaveCheckpoints, ComputeFID, SaveTextToCSV # Callbacks for saving and evaluation
from pe.logger import CSVPrint, LogPrint # Loggers for results
from pe.constant.data import VARIATION_API_FOLD_ID_COLUMN_NAME # Constant for column name

pd.options.mode.copy_on_write = True

# %% [markdown]
# ### 2. Configuration
#
# Set the input/output paths, model parameters, and PE settings here.

# %%
# --- Configuration --- 
# Input CSV file path (Relative to this notebook)
input_csv_path = "real_estate_synthetic_data/basic_call_transcripts.csv"
# Column containing the text transcripts in your CSV
text_column_name = "TranscriptText"
# Columns containing labels (if any, leave empty for unconditional generation)
label_columns = [] # e.g., ["BrokerName"] if you want to condition on BrokerName

# Output directory for results and logs
exp_folder = "results/text/call_transcripts_openai_notebook"
# Directory where prompt files will be stored/read from
prompt_folder = "prompts/call_transcripts"

# LLM Configuration
# Consider using "gpt-4o-mini" or other suitable models
llm_model = "gpt-4o-mini"
# Adjust based on expected transcript length
max_completion_tokens = 256 
llm_temperature = 1.2 # Controls randomness (higher means more random)
llm_threads = 4 # Number of parallel API calls

# API Configuration (LLMAugPE)
# Adjust based on transcript characteristics
min_word_count_variation = 50
word_count_std_variation = 50 # Std deviation for word count variation
token_to_word_ratio_variation = 1.5 # Estimated ratio for token limits
max_completion_tokens_limit_variation = 512 # Hard limit for variation tokens
# Set blank_probabilities if using masking/blanking in variation prompt
blank_probabilities_variation = None # Example: 0.5 or [0.1, 0.2, ...] per iteration

# Embedding Configuration
# Options: "stsb-roberta-base-v2", "sentence-t5-base", etc.
embedding_model = "stsb-roberta-base-v2"

# Population Configuration
initial_variation_fold = 3 # Folds for initial random generation
next_variation_fold = 3 # Folds for subsequent iterations
keep_selected_population = True # Keep best samples from previous iteration
selection_mode_population = "rank" # "rank" or "sample"

# PE Runner Configuration
# Number of samples per iteration (first element is initial, rest are for iterations)
# Generates 5000 samples for 10 refinement iterations (+1 initial)
num_samples_schedule = [100] * 11 
# Privacy parameters
target_epsilon = 1.0
# Delta will be calculated based on data size later

# %% [markdown]
# ### 3. Create Prompt Files
#
# This cell creates the necessary JSON prompt files for the LLM API.

# %%
# Create the directory for prompts if it doesn't exist
os.makedirs(prompt_folder, exist_ok=True)

# --- Create random_api_prompt.json ---
random_prompt_path = os.path.join(prompt_folder, "random_api_prompt.json")
random_prompt = {
    "message_template": [
        {
            "role": "system",
            "content": "You are required to write a realistic call transcript between two people discussing real estate or mortgage-related topics. Ensure the conversation includes typical dialogue elements like greetings, questions, confirmations, and potentially mentions of financial details or personal information in a natural way. Remove any PII or sensitive information, and swap any names, addresses, or other identifying information with generic placeholders like [address],[number], [ssn]."
        },
        {
            "role": "user",
            "content": "Generate a call transcript about a real estate showing follow-up or mortgage pre-approval discussion."
        }
    ]
}
with open(random_prompt_path, 'w') as f:
    json.dump(random_prompt, f, indent=4)
print(f"Created random prompt file at: {random_prompt_path}")

# --- Create variation_api_prompt.json ---
variation_prompt_path = os.path.join(prompt_folder, "variation_api_prompt.json")
variation_prompt = {
    "message_template": [
        {
            "role": "system",
            "content": "You are a helpful assistant that modifies text while maintaining its core meaning and style. You will be given a call transcript. You need to remove all PII and information that would be considered sensitive or confidential, and swap any names, addresses, or other identifying information with generic placeholders like [address],[number], [ssn]."
        },
        {
            "role": "user",
            "content": "Please rephrase the following call transcript {tone}, keeping it realistic for a real estate or mortgage context:\n{sample}"
        }
    ],
    "replacement_rules": [
        {
            "constraints": {},
            "replacements": {
                "tone": [
                    "in a slightly different way",
                    "using different wording",
                    "with minor variations",
                    "while preserving the key information",
                    "in a similar conversational style"
                ]
            }
        }
    ]
}
# If you want to use blanking/masking similar to the yelp_openai example,
# you would need a more complex prompt structure like the one commented out below.
# variation_prompt = {
#     "message_template": [
#         {
#             "role": "system",
#             "content": "You are a helpful assistant that fills in blanks in text while maintaining the original context and style."
#         },
#         {
#             "role": "user",
#             "content": "Based on the context of a real estate or mortgage call transcript, fill in the blanks in the input sentences. If there are no blanks, output the original input sentences.\nInput: {masked_sample}\nFill-in-Blanks and your answer MUST be exactly {word_count} words:"
#         }
#     ]
# }
with open(variation_prompt_path, 'w') as f:
    json.dump(variation_prompt, f, indent=4)
print(f"Created variation prompt file at: {variation_prompt_path}")
# Out:
# Created random prompt file at: prompts/call_transcripts/random_api_prompt.json
# Created variation prompt file at: prompts/call_transcripts/variation_api_prompt.json

# %% [markdown]
# ### 4. Setup Environment and Logging

# %%
# Load environment variables (like OPENAI_API_KEY from .env file)
load_dotenv()
print("Environment variables loaded.")

# Setup logging
os.makedirs(exp_folder, exist_ok=True)
log_file_path = os.path.join(exp_folder, "log.txt")
setup_logging(log_file=log_file_path)
logging.info("Starting synthetic call transcript generation.")
print(f"Logging setup complete. Log file: {log_file_path}")
# Out:
# Environment variables loaded.
# Logging setup complete. Log file: results/text/call_transcripts_openai_notebook/log.txt

# %% [markdown]
# ### 5. Load Private Data

# %%
logging.info(f"Loading private data from: {input_csv_path}")
try:
    data = TextCSV(
        csv_path=input_csv_path,
        label_columns=label_columns, # Use configured label columns
        text_column=text_column_name # Use configured text column
    )
    num_private_samples = len(data.data_frame)
    logging.info(f"Loaded {num_private_samples} private samples.")
    print(f"Loaded {num_private_samples} private samples from {input_csv_path}")
    if num_private_samples == 0:
         raise ValueError("Loaded data is empty. Please check CSV path and content.")
    
    # Display first few rows (optional)
    # print("Sample data:")
    # print(data.data_frame.head())

except FileNotFoundError:
    logging.error(f"Error: Input CSV file not found at {input_csv_path}")
    print(f"Error: Input CSV file not found at {input_csv_path}")
    # Stop execution or handle error appropriately in a notebook context
    raise 
except ValueError as e:
     logging.error(f"Error loading data: {e}")
     print(f"Error loading data: {e}")
     raise
except Exception as e:
    logging.error(f"An unexpected error occurred during data loading: {e}")
    print(f"An unexpected error occurred during data loading: {e}")
    raise
# Out:
# Loaded 10000 private samples from real_estate_synthetic_data/basic_call_transcripts.csv

# %% [markdown]
# ### 6. Define PE Components

# %%
# Define LLM
llm = OpenAILLM(
    max_completion_tokens=max_completion_tokens,
    model=llm_model,
    temperature=llm_temperature,
    num_threads=llm_threads
)
logging.info(f"LLM defined: {llm_model}")

# Define API for PE (using LLMAugPE)
api = LLMAugPE(
    llm=llm,
    random_api_prompt_file=random_prompt_path,
    variation_api_prompt_file=variation_prompt_path,
    min_word_count=min_word_count_variation,
    word_count_std=word_count_std_variation,
    token_to_word_ratio=token_to_word_ratio_variation,
    max_completion_tokens_limit=max_completion_tokens_limit_variation,
    blank_probabilities=blank_probabilities_variation,
)
logging.info("LLMAugPE API defined.")

# Define Embedding model
embedding = SentenceTransformer(model=embedding_model)
logging.info(f"Embedding defined: {embedding_model}")

# Define Histogram method
histogram = NearestNeighbors(
    embedding=embedding,
    mode="L2", # L2 distance for nearest neighbors
    lookahead_degree=0, # No lookahead in this example
)
logging.info("NearestNeighbors Histogram defined.")

# Define Population update strategy
population = PEPopulation(
    api=api,
    initial_variation_api_fold=initial_variation_fold,
    next_variation_api_fold=next_variation_fold,
    keep_selected=keep_selected_population,
    selection_mode=selection_mode_population
)
logging.info("PEPopulation defined.")
# Out:
# 04/16/2025 01:41:57 AM [pe] [INFO ]  Using 1 OpenAI API keys
# INFO:pe:Using 1 OpenAI API keys
# 04/16/2025 01:41:57 AM [pe] [INFO ]  Using 4 threads for making concurrent API calls
# INFO:pe:Using 4 threads for making concurrent API calls
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %% [markdown]
# ### 7. Define Callbacks and Loggers

# %%
# Define Callbacks
save_checkpoints = SaveCheckpoints(os.path.join(exp_folder, "checkpoint"))
compute_fid = ComputeFID(
    priv_data=data,
    embedding=embedding,
    # Only compute FID on samples generated by random API initially, or final variation samples later
    filter_criterion={VARIATION_API_FOLD_ID_COLUMN_NAME: -1}
)
save_text_to_csv = SaveTextToCSV(output_folder=os.path.join(exp_folder, "synthetic_text"))
logging.info("Callbacks defined: SaveCheckpoints, ComputeFID, SaveTextToCSV")

# Define Loggers
csv_print = CSVPrint(output_folder=exp_folder)
log_print = LogPrint() # Prints progress to standard logging output
logging.info("Loggers defined: CSVPrint, LogPrint")
# Out:
# 04/16/2025 01:42:44 AM [pe] [INFO ]  Embedding: computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 10000/10000 samples
# INFO:pe:Embedding: computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 10000/10000 samples
# 04/16/2025 01:43:57 AM [pe] [INFO ]  Embedding: finished computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 10000/10000 samples
# INFO:pe:Embedding: finished computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 10000/10000 samples

# %% [markdown]
# ### 8. Calculate Delta for DP

# %%
# Calculate delta for DP based on the number of private samples loaded earlier
# Avoid division by zero or log(1) if only 1 sample
if num_private_samples <= 1:
     delta = 1e-5 # Assign a small default delta if few samples
     logging.warning(f"Number of private samples is {num_private_samples}. Using default delta={delta}")
else:
     # Standard delta calculation: 1 / (N * log N)
     delta = 1.0 / (num_private_samples * np.log(num_private_samples))
logging.info(f"Using delta={delta} based on {num_private_samples} private samples.")
print(f"Calculated delta={delta} for DP.")
# Out:
# Calculated delta=1.0857362047581295e-05 for DP.

# %% [markdown]
# ### 9. Define and Run PE Runner

# %%
# Define PE Runner
pe_runner = PE(
    priv_data=data,
    population=population,
    histogram=histogram,
    callbacks=[save_checkpoints, save_text_to_csv, compute_fid],
    loggers=[csv_print, log_print], # LogPrint will output to the notebook console/log file
    # DP mechanism defaults to Gaussian if not specified
)
logging.info("PE Runner defined.")

# Run Private Evolution
logging.info(f"Starting PE run with epsilon={target_epsilon}, delta={delta}")
print(f"Starting PE run... Check logs in '{log_file_path}' and results in '{exp_folder}'")
pe_runner.run(
    num_samples_schedule=num_samples_schedule,
    delta=delta,
    epsilon=target_epsilon,
    checkpoint_path=os.path.join(exp_folder, "checkpoint"), # Resume from checkpoint if exists
)

logging.info("Synthetic call transcript generation finished.")
print("PE run finished!")
# Out:
# /Users/yawetse/Developer/github/yawetse/private-ml/.venv/lib/python3.13/site-packages/pe/dp/gaussian.py:23: RuntimeWarning: overflow encountered in exp
#   if np.isinf(np.exp(eps)):
# 04/16/2025 01:44:10 AM [pe] [INFO ]  DP epsilon=1.0, delta=1.0857362047581295e-05, noise_multiplier=11.738744309185014, num_iterations=10.
# INFO:pe:DP epsilon=1.0, delta=1.0857362047581295e-05, noise_multiplier=11.738744309185014, num_iterations=10.
# 04/16/2025 01:44:10 AM [pe] [WARNI]  fraction_per_label_id is not provided. Assuming the fraction of label ids in private data is public information.
# WARNING:pe:fraction_per_label_id is not provided. Assuming the fraction of label ids in private data is public information.
# 04/16/2025 01:44:10 AM [pe] [INFO ]  Population: generating 100*4 initial synthetic samples for label
# INFO:pe:Population: generating 100*4 initial synthetic samples for label
# 04/16/2025 01:44:10 AM [pe] [INFO ]  RANDOM API: creating 100 samples for label
# INFO:pe:RANDOM API: creating 100 samples for label
# 04/16/2025 01:44:10 AM [pe] [INFO ]  RANDOM API: producing LLM requests
# INFO:pe:RANDOM API: producing LLM requests
# 04/16/2025 01:44:10 AM [pe] [INFO ]  RANDOM API: getting LLM responses
# INFO:pe:RANDOM API: getting LLM responses
# 04/16/2025 01:44:10 AM [pe] [INFO ]  Workload [1]
# Starting PE run... Check logs in 'results/text/call_transcripts_openai_notebook/log.txt' and results in 'results/text/call_transcripts_openai_notebook'
# INFO:pe:Workload [1]
#   0%|          | 0/100 [00:00<?, ?it/s]04/16/2025 01:44:10 AM [pe] [INFO ]  Workload [2]
# INFO:pe:Workload [2]
# 04/16/2025 01:44:10 AM [pe] [INFO ]  Workload [3]
# INFO:pe:Workload [3]
# 04/16/2025 01:44:10 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:14 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:14 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:14 AM [pe] [INFO ]  Workload [4]
#   1%|          | 1/100 [00:04<06:48,  4.12s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:14 AM [pe] [INFO ]  Workload [4]
#   2%|▏         | 2/100 [00:04<02:52,  1.76s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:17 AM [pe] [INFO ]  Workload [4]
#   5%|▌         | 5/100 [00:06<01:43,  1.09s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:17 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:17 AM [pe] [INFO ]  Workload [4]
#   7%|▋         | 7/100 [00:07<01:10,  1.32it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:18 AM [pe] [INFO ]  Workload [4]
#   8%|▊         | 8/100 [00:08<01:13,  1.25it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:21 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:21 AM [pe] [INFO ]  Workload [4]
#   9%|▉         | 9/100 [00:10<01:50,  1.21s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:21 AM [pe] [INFO ]  Workload [4]
#  11%|█         | 11/100 [00:10<01:05,  1.36it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:22 AM [pe] [INFO ]  Workload [4]
#  12%|█▏        | 12/100 [00:11<01:05,  1.34it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:25 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:25 AM [pe] [INFO ]  Workload [4]
#  13%|█▎        | 13/100 [00:15<02:05,  1.45s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:28 AM [pe] [INFO ]  Workload [4]
#  14%|█▍        | 14/100 [00:18<02:38,  1.84s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:28 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:28 AM [pe] [INFO ]  Workload [4]
#  17%|█▋        | 17/100 [00:18<01:14,  1.11it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:29 AM [pe] [INFO ]  Workload [4]
#  18%|█▊        | 18/100 [00:18<01:03,  1.29it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:32 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:32 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:34 AM [pe] [INFO ]  Workload [4]
#  19%|█▉        | 19/100 [00:23<02:23,  1.77s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:35 AM [pe] [INFO ]  Workload [4]
#  20%|██        | 20/100 [00:25<02:11,  1.64s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:36 AM [pe] [INFO ]  Workload [4]
#  23%|██▎       | 23/100 [00:26<01:16,  1.01it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:38 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:38 AM [pe] [INFO ]  Workload [4]
#  24%|██▍       | 24/100 [00:27<01:26,  1.13s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:40 AM [pe] [INFO ]  Workload [4]
#  26%|██▌       | 26/100 [00:29<01:13,  1.01it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:41 AM [pe] [INFO ]  Workload [4]
#  27%|██▋       | 27/100 [00:30<01:12,  1.01it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:42 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:42 AM [pe] [INFO ]  Workload [4]
#  28%|██▊       | 28/100 [00:31<01:19,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:43 AM [pe] [INFO ]  Workload [4]
#  30%|███       | 30/100 [00:32<01:00,  1.16it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:46 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:47 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:47 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:49 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:50 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:52 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:53 AM [pe] [INFO ]  Workload [4]
#  31%|███       | 31/100 [00:43<03:22,  2.93s/it]INFO:pe:Workload [4]
# 04/16/2025 01:44:54 AM [pe] [INFO ]  Workload [4]
#  39%|███▉      | 39/100 [00:44<00:56,  1.09it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:56 AM [pe] [INFO ]  Workload [4]
#  40%|████      | 40/100 [00:45<00:57,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:44:57 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:58 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:44:59 AM [pe] [INFO ]  Workload [4]
#  41%|████      | 41/100 [00:48<01:16,  1.29s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:02 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:02 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:03 AM [pe] [INFO ]  Workload [4]
#  44%|████▍     | 44/100 [00:52<01:11,  1.27s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:03 AM [pe] [INFO ]  Workload [4]
#  47%|████▋     | 47/100 [00:52<00:45,  1.16it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:05 AM [pe] [INFO ]  Workload [4]
#  48%|████▊     | 48/100 [00:55<00:55,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:06 AM [pe] [INFO ]  Workload [4]
#  49%|████▉     | 49/100 [00:55<00:48,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:07 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:07 AM [pe] [INFO ]  Workload [4]
#  50%|█████     | 50/100 [00:57<00:55,  1.10s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:10 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:15 AM [pe] [INFO ]  Workload [4]
#  52%|█████▏    | 52/100 [01:04<01:35,  1.99s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:15 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:16 AM [pe] [INFO ]  Workload [4]
#  54%|█████▍    | 54/100 [01:05<01:12,  1.57s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:18 AM [pe] [INFO ]  Workload [4]
#  57%|█████▋    | 57/100 [01:07<00:49,  1.15s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:18 AM [pe] [INFO ]  Workload [4]
#  58%|█████▊    | 58/100 [01:08<00:45,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:20 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:21 AM [pe] [INFO ]  Workload [4]
#  59%|█████▉    | 59/100 [01:10<00:56,  1.39s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:22 AM [pe] [INFO ]  Workload [4]
#  61%|██████    | 61/100 [01:11<00:41,  1.05s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:23 AM [pe] [INFO ]  Workload [4]
#  62%|██████▏   | 62/100 [01:12<00:36,  1.05it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:24 AM [pe] [INFO ]  Workload [4]
#  63%|██████▎   | 63/100 [01:13<00:36,  1.02it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:25 AM [pe] [INFO ]  Workload [4]
#  64%|██████▍   | 64/100 [01:14<00:38,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:25 AM [pe] [INFO ]  Workload [4]
#  65%|██████▌   | 65/100 [01:15<00:31,  1.11it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:26 AM [pe] [INFO ]  Workload [4]
#  66%|██████▌   | 66/100 [01:15<00:28,  1.17it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:27 AM [pe] [INFO ]  Workload [4]
#  67%|██████▋   | 67/100 [01:16<00:29,  1.12it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:30 AM [pe] [INFO ]  Workload [4]
#  68%|██████▊   | 68/100 [01:19<00:42,  1.32s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:31 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:34 AM [pe] [INFO ]  Workload [4]
#  70%|███████   | 70/100 [01:23<00:49,  1.64s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:35 AM [pe] [INFO ]  Workload [4]
#  72%|███████▏  | 72/100 [01:25<00:37,  1.33s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:37 AM [pe] [INFO ]  Workload [4]
#  74%|███████▍  | 74/100 [01:27<00:31,  1.23s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:38 AM [pe] [INFO ]  Workload [4]
#  75%|███████▌  | 75/100 [01:27<00:25,  1.02s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:39 AM [pe] [INFO ]  Workload [4]
#  76%|███████▌  | 76/100 [01:28<00:27,  1.13s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:39 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:42 AM [pe] [INFO ]  Workload [4]
#  78%|███████▊  | 78/100 [01:31<00:25,  1.18s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:43 AM [pe] [INFO ]  Workload [4]
#  79%|███████▉  | 79/100 [01:32<00:25,  1.21s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:43 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:44 AM [pe] [INFO ]  Workload [4]
#  81%|████████  | 81/100 [01:33<00:18,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:45 AM [pe] [INFO ]  Workload [4]
#  82%|████████▏ | 82/100 [01:35<00:18,  1.01s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:47 AM [pe] [INFO ]  Workload [4]
#  83%|████████▎ | 83/100 [01:36<00:20,  1.23s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:48 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:49 AM [pe] [INFO ]  Workload [4]
#  84%|████████▍ | 84/100 [01:38<00:22,  1.40s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:49 AM [pe] [INFO ]  Workload [4]
#  86%|████████▌ | 86/100 [01:39<00:12,  1.13it/s]INFO:pe:Workload [4]
# 04/16/2025 01:45:52 AM [pe] [INFO ]  Workload [4]
#  87%|████████▋ | 87/100 [01:41<00:15,  1.16s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:54 AM [pe] [INFO ]  Workload [4]
#  88%|████████▊ | 88/100 [01:43<00:17,  1.49s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:55 AM [pe] [INFO ]  Workload [4]
#  89%|████████▉ | 89/100 [01:44<00:14,  1.35s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:55 AM [pe] [INFO ]  Workload [4]
#  90%|█████████ | 90/100 [01:45<00:11,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:55 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:45:57 AM [pe] [INFO ]  Workload [4]
#  92%|█████████▏| 92/100 [01:47<00:08,  1.05s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:58 AM [pe] [INFO ]  Workload [4]
#  93%|█████████▎| 93/100 [01:48<00:07,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:45:59 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:00 AM [pe] [INFO ]  Workload [4]
#  94%|█████████▍| 94/100 [01:50<00:07,  1.24s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:01 AM [pe] [INFO ]  Workload [4]
#  96%|█████████▌| 96/100 [01:50<00:03,  1.08it/s]INFO:pe:Workload [4]
# 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
# 04/16/2025 01:46:09 AM [pe] [INFO ]  RANDOM API: constructing data
# INFO:pe:RANDOM API: constructing data
# 04/16/2025 01:46:09 AM [pe] [INFO ]  RANDOM API: finished creating 100 samples for label
# INFO:pe:RANDOM API: finished creating 100 samples for label
# 04/16/2025 01:46:09 AM [pe] [INFO ]  VARIATION API: creating variations for 100 samples
# INFO:pe:VARIATION API: creating variations for 100 samples
# 04/16/2025 01:46:09 AM [pe] [INFO ]  VARIATION API: producing LLM requests
# INFO:pe:VARIATION API: producing LLM requests
# 04/16/2025 01:46:09 AM [pe] [INFO ]  VARIATION API: getting LLM responses
# INFO:pe:VARIATION API: getting LLM responses
# 04/16/2025 01:46:09 AM [pe] [INFO ]  Workload [1]
# INFO:pe:Workload [1]
#   0%|          | 0/100 [00:00<?, ?it/s]04/16/2025 01:46:09 AM [pe] [INFO ]  Workload [2]
# INFO:pe:Workload [2]
# 04/16/2025 01:46:09 AM [pe] [INFO ]  Workload [3]
# INFO:pe:Workload [3]
# 04/16/2025 01:46:09 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:13 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:14 AM [pe] [INFO ]  Workload [4]
#   1%|          | 1/100 [00:05<08:27,  5.13s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:17 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:18 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:18 AM [pe] [INFO ]  Workload [4]
#   5%|▌         | 5/100 [00:09<02:39,  1.67s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:21 AM [pe] [INFO ]  Workload [4]
#   7%|▋         | 7/100 [00:11<02:20,  1.51s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:23 AM [pe] [INFO ]  Workload [4]
#   9%|▉         | 9/100 [00:13<01:59,  1.32s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:23 AM [pe] [INFO ]  Workload [4]
#  11%|█         | 11/100 [00:14<01:22,  1.08it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:26 AM [pe] [INFO ]  Workload [4]
#  13%|█▎        | 13/100 [00:17<01:36,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:26 AM [pe] [INFO ]  Workload [4]
#  14%|█▍        | 14/100 [00:17<01:27,  1.02s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:27 AM [pe] [INFO ]  Workload [4]
#  15%|█▌        | 15/100 [00:18<01:26,  1.02s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:28 AM [pe] [INFO ]  Workload [4]
#  16%|█▌        | 16/100 [00:19<01:21,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:30 AM [pe] [INFO ]  Workload [4]
#  17%|█▋        | 17/100 [00:21<01:45,  1.27s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:31 AM [pe] [INFO ]  Workload [4]
#  18%|█▊        | 18/100 [00:22<01:38,  1.20s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:32 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:35 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:35 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:35 AM [pe] [INFO ]  Workload [4]
#  19%|█▉        | 19/100 [00:26<02:37,  1.94s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:37 AM [pe] [INFO ]  Workload [4]
#  24%|██▍       | 24/100 [00:28<01:04,  1.17it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:38 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:38 AM [pe] [INFO ]  Workload [4]
#  25%|██▌       | 25/100 [00:29<01:08,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:39 AM [pe] [INFO ]  Workload [4]
#  27%|██▋       | 27/100 [00:30<00:59,  1.22it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:42 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:43 AM [pe] [INFO ]  Workload [4]
#  28%|██▊       | 28/100 [00:33<01:31,  1.27s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:43 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:45 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:47 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:48 AM [pe] [INFO ]  Workload [4]
#  29%|██▉       | 29/100 [00:38<02:24,  2.03s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:48 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:49 AM [pe] [INFO ]  Workload [4]
#  34%|███▍      | 34/100 [00:39<01:03,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:50 AM [pe] [INFO ]  Workload [4]
#  36%|███▌      | 36/100 [00:41<00:55,  1.14it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:51 AM [pe] [INFO ]  Workload [4]
#  37%|███▋      | 37/100 [00:42<00:54,  1.16it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:53 AM [pe] [INFO ]  Workload [4]
#  38%|███▊      | 38/100 [00:44<01:13,  1.18s/it]INFO:pe:Workload [4]
# 04/16/2025 01:46:54 AM [pe] [INFO ]  Workload [4]
#  41%|████      | 41/100 [00:44<00:41,  1.42it/s]INFO:pe:Workload [4]
# 04/16/2025 01:46:56 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:57 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:59 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:46:59 AM [pe] [INFO ]  Workload [4]
#  42%|████▏     | 42/100 [00:50<01:29,  1.55s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:00 AM [pe] [INFO ]  Workload [4]
#  46%|████▌     | 46/100 [00:51<00:49,  1.09it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:02 AM [pe] [INFO ]  Workload [4]
#  47%|████▋     | 47/100 [00:52<00:50,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:03 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:03 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:05 AM [pe] [INFO ]  Workload [4]
#  48%|████▊     | 48/100 [00:56<01:11,  1.37s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:07 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:08 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:08 AM [pe] [INFO ]  Workload [4]
#  50%|█████     | 50/100 [00:59<01:12,  1.45s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:09 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:11 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:11 AM [pe] [INFO ]  Workload [4]
#  54%|█████▍    | 54/100 [01:02<00:51,  1.12s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:12 AM [pe] [INFO ]  Workload [4]
#  57%|█████▋    | 57/100 [01:02<00:33,  1.28it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:13 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:14 AM [pe] [INFO ]  Workload [4]
#  58%|█████▊    | 58/100 [01:04<00:40,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:16 AM [pe] [INFO ]  Workload [4]
#  59%|█████▉    | 59/100 [01:07<00:47,  1.16s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:16 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:16 AM [pe] [INFO ]  Workload [4]
#  61%|██████    | 61/100 [01:07<00:34,  1.13it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:18 AM [pe] [INFO ]  Workload [4]
#  63%|██████▎   | 63/100 [01:09<00:32,  1.14it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:19 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:20 AM [pe] [INFO ]  Workload [4]
#  64%|██████▍   | 64/100 [01:11<00:36,  1.01s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:24 AM [pe] [INFO ]  Workload [4]
#  66%|██████▌   | 66/100 [01:14<00:45,  1.32s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:24 AM [pe] [INFO ]  Workload [4]
#  69%|██████▉   | 69/100 [01:15<00:25,  1.20it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:26 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:31 AM [pe] [INFO ]  Workload [4]
#  70%|███████   | 70/100 [01:21<00:54,  1.81s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:31 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:32 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:33 AM [pe] [INFO ]  Workload [4]
#  72%|███████▏  | 72/100 [01:24<00:44,  1.59s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:33 AM [pe] [INFO ]  Workload [4]
#  75%|███████▌  | 75/100 [01:24<00:24,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:34 AM [pe] [INFO ]  Workload [4]
#  76%|███████▌  | 76/100 [01:25<00:23,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:38 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:39 AM [pe] [INFO ]  Workload [4]
#  77%|███████▋  | 77/100 [01:30<00:38,  1.66s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:40 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:41 AM [pe] [INFO ]  Workload [4]
#  81%|████████  | 81/100 [01:32<00:21,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:41 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:43 AM [pe] [INFO ]  Workload [4]
#  84%|████████▍ | 84/100 [01:34<00:15,  1.06it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:45 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:45 AM [pe] [INFO ]  Workload [4]
#  85%|████████▌ | 85/100 [01:36<00:17,  1.15s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:46 AM [pe] [INFO ]  Workload [4]
#  86%|████████▌ | 86/100 [01:37<00:14,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:46 AM [pe] [INFO ]  Workload [4]
#  88%|████████▊ | 88/100 [01:37<00:08,  1.37it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:49 AM [pe] [INFO ]  Workload [4]
#  89%|████████▉ | 89/100 [01:40<00:13,  1.20s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:50 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:50 AM [pe] [INFO ]  Workload [4]
#  90%|█████████ | 90/100 [01:41<00:10,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:47:51 AM [pe] [INFO ]  Workload [4]
#  92%|█████████▏| 92/100 [01:41<00:06,  1.31it/s]INFO:pe:Workload [4]
# 04/16/2025 01:47:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:47:54 AM [pe] [INFO ]  Workload [4]
#  93%|█████████▎| 93/100 [01:45<00:09,  1.30s/it]INFO:pe:Workload [4]
# 100%|██████████| 100/100 [01:51<00:00,  1.11s/it]
# 04/16/2025 01:48:00 AM [pe] [INFO ]  VARIATION API: constructing data
# INFO:pe:VARIATION API: constructing data
# 04/16/2025 01:48:00 AM [pe] [INFO ]  VARIATION API: finished creating variations for 100 samples
# INFO:pe:VARIATION API: finished creating variations for 100 samples
# 04/16/2025 01:48:00 AM [pe] [INFO ]  VARIATION API: creating variations for 100 samples
# INFO:pe:VARIATION API: creating variations for 100 samples
# 04/16/2025 01:48:00 AM [pe] [INFO ]  VARIATION API: producing LLM requests
# INFO:pe:VARIATION API: producing LLM requests
# 04/16/2025 01:48:00 AM [pe] [INFO ]  VARIATION API: getting LLM responses
# INFO:pe:VARIATION API: getting LLM responses
# 04/16/2025 01:48:00 AM [pe] [INFO ]  Workload [1]
# INFO:pe:Workload [1]
# 04/16/2025 01:48:00 AM [pe] [INFO ]  Workload [2]
# INFO:pe:Workload [2]
#   0%|          | 0/100 [00:00<?, ?it/s]04/16/2025 01:48:00 AM [pe] [INFO ]  Workload [3]
# INFO:pe:Workload [3]
# 04/16/2025 01:48:00 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:03 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:03 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:04 AM [pe] [INFO ]  Workload [4]
#   1%|          | 1/100 [00:03<06:11,  3.75s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:05 AM [pe] [INFO ]  Workload [4]
#   3%|▎         | 3/100 [00:04<01:59,  1.24s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:07 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:07 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:08 AM [pe] [INFO ]  Workload [4]
#   5%|▌         | 5/100 [00:08<02:29,  1.58s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:09 AM [pe] [INFO ]  Workload [4]
#   8%|▊         | 8/100 [00:08<01:16,  1.21it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:12 AM [pe] [INFO ]  Workload [4]
#   9%|▉         | 9/100 [00:12<02:02,  1.35s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:13 AM [pe] [INFO ]  Workload [4]
#  11%|█         | 11/100 [00:12<01:26,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:13 AM [pe] [INFO ]  Workload [4]
#  12%|█▏        | 12/100 [00:13<01:18,  1.13it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:16 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:16 AM [pe] [INFO ]  Workload [4]
#  13%|█▎        | 13/100 [00:15<01:41,  1.17s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:17 AM [pe] [INFO ]  Workload [4]
#  15%|█▌        | 15/100 [00:16<01:24,  1.00it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:17 AM [pe] [INFO ]  Workload [4]
#  16%|█▌        | 16/100 [00:17<01:10,  1.19it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:18 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:20 AM [pe] [INFO ]  Workload [4]
#  17%|█▋        | 17/100 [00:19<01:40,  1.22s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:21 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:22 AM [pe] [INFO ]  Workload [4]
#  19%|█▉        | 19/100 [00:21<01:32,  1.14s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:23 AM [pe] [INFO ]  Workload [4]
#  21%|██        | 21/100 [00:22<01:07,  1.17it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:26 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:26 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:28 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:31 AM [pe] [INFO ]  Workload [4]
#  23%|██▎       | 23/100 [00:30<02:30,  1.95s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:35 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:36 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:37 AM [pe] [INFO ]  Workload [4]
#  29%|██▉       | 29/100 [00:36<01:40,  1.42s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:39 AM [pe] [INFO ]  Workload [4]
#  35%|███▌      | 35/100 [00:38<00:57,  1.13it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:39 AM [pe] [INFO ]  Workload [4]
#  36%|███▌      | 36/100 [00:38<00:52,  1.21it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:41 AM [pe] [INFO ]  Workload [4]
#  37%|███▋      | 37/100 [00:40<01:01,  1.02it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:41 AM [pe] [INFO ]  Workload [4]
#  38%|███▊      | 38/100 [00:40<00:52,  1.17it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:42 AM [pe] [INFO ]  Workload [4]
#  39%|███▉      | 39/100 [00:42<00:55,  1.09it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:42 AM [pe] [INFO ]  Workload [4]
#  40%|████      | 40/100 [00:42<00:45,  1.32it/s]INFO:pe:Workload [4]
# 04/16/2025 01:48:45 AM [pe] [INFO ]  Workload [4]
#  41%|████      | 41/100 [00:44<01:08,  1.17s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:46 AM [pe] [INFO ]  Workload [4]
#  42%|████▏     | 42/100 [00:45<01:01,  1.05s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:46 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:47 AM [pe] [INFO ]  Workload [4]
#  43%|████▎     | 43/100 [00:46<01:02,  1.09s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:49 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:51 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:51 AM [pe] [INFO ]  Workload [4]
#  45%|████▌     | 45/100 [00:50<01:20,  1.46s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:54 AM [pe] [INFO ]  Workload [4]
#  48%|████▊     | 48/100 [00:53<01:04,  1.24s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:54 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:56 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:48:56 AM [pe] [INFO ]  Workload [4]
#  49%|████▉     | 49/100 [00:55<01:09,  1.36s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:59 AM [pe] [INFO ]  Workload [4]
#  52%|█████▏    | 52/100 [00:58<00:56,  1.18s/it]INFO:pe:Workload [4]
# 04/16/2025 01:48:59 AM [pe] [INFO ]  Workload [4]
#  53%|█████▎    | 53/100 [00:58<00:49,  1.06s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:00 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:00 AM [pe] [INFO ]  Workload [4]
#  54%|█████▍    | 54/100 [01:00<00:49,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:04 AM [pe] [INFO ]  Workload [4]
#  56%|█████▌    | 56/100 [01:03<00:59,  1.36s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:04 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:04 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:06 AM [pe] [INFO ]  Workload [4]
#  57%|█████▋    | 57/100 [01:05<01:04,  1.51s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:06 AM [pe] [INFO ]  Workload [4]
#  60%|██████    | 60/100 [01:06<00:35,  1.14it/s]INFO:pe:Workload [4]
# 04/16/2025 01:49:08 AM [pe] [INFO ]  Workload [4]
#  61%|██████    | 61/100 [01:07<00:36,  1.06it/s]INFO:pe:Workload [4]
# 04/16/2025 01:49:09 AM [pe] [INFO ]  Workload [4]
#  62%|██████▏   | 62/100 [01:09<00:40,  1.06s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:13 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:13 AM [pe] [INFO ]  Workload [4]
#  63%|██████▎   | 63/100 [01:12<01:01,  1.66s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:15 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:17 AM [pe] [INFO ]  Workload [4]
#  67%|██████▋   | 67/100 [01:16<00:40,  1.23s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:17 AM [pe] [INFO ]  Workload [4]
#  69%|██████▉   | 69/100 [01:16<00:28,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:49:17 AM [pe] [INFO ]  Workload [4]
#  70%|███████   | 70/100 [01:17<00:25,  1.19it/s]INFO:pe:Workload [4]
# 04/16/2025 01:49:18 AM [pe] [INFO ]  Workload [4]
#  71%|███████   | 71/100 [01:18<00:25,  1.16it/s]INFO:pe:Workload [4]
# 04/16/2025 01:49:21 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:23 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:24 AM [pe] [INFO ]  Workload [4]
#  72%|███████▏  | 72/100 [01:23<00:51,  1.85s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:24 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:27 AM [pe] [INFO ]  Workload [4]
#  76%|███████▌  | 76/100 [01:26<00:30,  1.26s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:28 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:32 AM [pe] [INFO ]  Workload [4]
#  78%|███████▊  | 78/100 [01:32<00:36,  1.67s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:32 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:33 AM [pe] [INFO ]  Workload [4]
#  81%|████████  | 81/100 [01:33<00:22,  1.20s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:37 AM [pe] [INFO ]  Workload [4]
#  83%|████████▎ | 83/100 [01:36<00:22,  1.30s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:37 AM [pe] [INFO ]  Workload [4]
#  84%|████████▍ | 84/100 [01:36<00:17,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:37 AM [pe] [INFO ]  Workload [4]
#  85%|████████▌ | 85/100 [01:37<00:15,  1.03s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:39 AM [pe] [INFO ]  Workload [4]
#  86%|████████▌ | 86/100 [01:38<00:15,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:41 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:42 AM [pe] [INFO ]  Workload [4]
#  87%|████████▋ | 87/100 [01:41<00:21,  1.64s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:42 AM [pe] [INFO ]  Workload [4]
#  89%|████████▉ | 89/100 [01:42<00:11,  1.02s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:43 AM [pe] [INFO ]  Workload [4]
#  90%|█████████ | 90/100 [01:42<00:09,  1.05it/s]INFO:pe:Workload [4]
# 04/16/2025 01:49:44 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:46 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:46 AM [pe] [INFO ]  Workload [4]
#  91%|█████████ | 91/100 [01:45<00:12,  1.42s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:47 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:48 AM [pe] [INFO ]  Workload [4]
#  94%|█████████▍| 94/100 [01:47<00:06,  1.05s/it]INFO:pe:Workload [4]
# 04/16/2025 01:49:51 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 100%|██████████| 100/100 [01:53<00:00,  1.14s/it]
# 04/16/2025 01:49:54 AM [pe] [INFO ]  VARIATION API: constructing data
# INFO:pe:VARIATION API: constructing data
# 04/16/2025 01:49:54 AM [pe] [INFO ]  VARIATION API: finished creating variations for 100 samples
# INFO:pe:VARIATION API: finished creating variations for 100 samples
# 04/16/2025 01:49:54 AM [pe] [INFO ]  VARIATION API: creating variations for 100 samples
# INFO:pe:VARIATION API: creating variations for 100 samples
# 04/16/2025 01:49:54 AM [pe] [INFO ]  VARIATION API: producing LLM requests
# INFO:pe:VARIATION API: producing LLM requests
# 04/16/2025 01:49:54 AM [pe] [INFO ]  VARIATION API: getting LLM responses
# INFO:pe:VARIATION API: getting LLM responses
# 04/16/2025 01:49:54 AM [pe] [INFO ]  Workload [1]
# INFO:pe:Workload [1]
# 04/16/2025 01:49:54 AM [pe] [INFO ]  Workload [2]
# INFO:pe:Workload [2]
#   0%|          | 0/100 [00:00<?, ?it/s]04/16/2025 01:49:54 AM [pe] [INFO ]  Workload [3]
# INFO:pe:Workload [3]
# 04/16/2025 01:49:54 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:56 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:57 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:49:57 AM [pe] [INFO ]  Workload [4]
#   1%|          | 1/100 [00:03<05:44,  3.48s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:00 AM [pe] [INFO ]  Workload [4]
#   3%|▎         | 3/100 [00:06<03:14,  2.01s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:01 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:02 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:05 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:06 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:07 AM [pe] [INFO ]  Workload [4]
#   5%|▌         | 5/100 [00:13<04:27,  2.82s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:08 AM [pe] [INFO ]  Workload [4]
#   9%|▉         | 9/100 [00:14<01:56,  1.28s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:10 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:13 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:15 AM [pe] [INFO ]  Workload [4]
#  11%|█         | 11/100 [00:20<02:41,  1.81s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:15 AM [pe] [INFO ]  Workload [4]
#  15%|█▌        | 15/100 [00:20<01:25,  1.01s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:17 AM [pe] [INFO ]  Workload [4]
#  16%|█▌        | 16/100 [00:22<01:33,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:17 AM [pe] [INFO ]  Workload [4]
#  17%|█▋        | 17/100 [00:23<01:28,  1.07s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:17 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:18 AM [pe] [INFO ]  Workload [4]
#  19%|█▉        | 19/100 [00:23<01:00,  1.34it/s]INFO:pe:Workload [4]
# 04/16/2025 01:50:20 AM [pe] [INFO ]  Workload [4]
#  20%|██        | 20/100 [00:26<01:27,  1.09s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:21 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:21 AM [pe] [INFO ]  Workload [4]
#  21%|██        | 21/100 [00:27<01:26,  1.10s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:21 AM [pe] [INFO ]  Workload [4]
#  23%|██▎       | 23/100 [00:27<00:54,  1.41it/s]INFO:pe:Workload [4]
# 04/16/2025 01:50:25 AM [pe] [INFO ]  Workload [4]
#  24%|██▍       | 24/100 [00:30<01:34,  1.25s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:25 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:26 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:26 AM [pe] [INFO ]  Workload [4]
#  25%|██▌       | 25/100 [00:31<01:32,  1.24s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:29 AM [pe] [INFO ]  Workload [4]
#  28%|██▊       | 28/100 [00:34<01:19,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:29 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:30 AM [pe] [INFO ]  Workload [4]
#  29%|██▉       | 29/100 [00:36<01:27,  1.23s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:34 AM [pe] [INFO ]  Workload [4]
#  32%|███▏      | 32/100 [00:40<01:24,  1.24s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:34 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:37 AM [pe] [INFO ]  Workload [4]
#  34%|███▍      | 34/100 [00:42<01:19,  1.21s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:38 AM [pe] [INFO ]  Workload [4]
#  36%|███▌      | 36/100 [00:44<01:11,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:39 AM [pe] [INFO ]  Workload [4]
#  38%|███▊      | 38/100 [00:45<00:54,  1.13it/s]INFO:pe:Workload [4]
# 04/16/2025 01:50:40 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:43 AM [pe] [INFO ]  Workload [4]
#  39%|███▉      | 39/100 [00:48<01:25,  1.40s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:44 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:45 AM [pe] [INFO ]  Workload [4]
#  41%|████      | 41/100 [00:51<01:18,  1.34s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:45 AM [pe] [INFO ]  Workload [4]
#  43%|████▎     | 43/100 [00:51<00:53,  1.07it/s]INFO:pe:Workload [4]
# 04/16/2025 01:50:47 AM [pe] [INFO ]  Workload [4]
#  44%|████▍     | 44/100 [00:52<00:54,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:50:47 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:48 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:50 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:51 AM [pe] [INFO ]  Workload [4]
#  46%|████▌     | 46/100 [00:56<01:11,  1.32s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:51 AM [pe] [INFO ]  Workload [4]
#  48%|████▊     | 48/100 [00:57<00:53,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:55 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:55 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:55 AM [pe] [INFO ]  Workload [4]
#  50%|█████     | 50/100 [01:01<01:07,  1.35s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:58 AM [pe] [INFO ]  Workload [4]
#  53%|█████▎    | 53/100 [01:03<00:51,  1.09s/it]INFO:pe:Workload [4]
# 04/16/2025 01:50:58 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:59 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:50:59 AM [pe] [INFO ]  Workload [4]
#  54%|█████▍    | 54/100 [01:05<00:55,  1.20s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:01 AM [pe] [INFO ]  Workload [4]
#  57%|█████▋    | 57/100 [01:07<00:41,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:03 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:04 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:05 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:08 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:08 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:08 AM [pe] [INFO ]  Workload [4]
#  58%|█████▊    | 58/100 [01:13<01:17,  1.85s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:10 AM [pe] [INFO ]  Workload [4]
#  64%|██████▍   | 64/100 [01:15<00:35,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:11 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:12 AM [pe] [INFO ]  Workload [4]
#  65%|██████▌   | 65/100 [01:17<00:38,  1.11s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:14 AM [pe] [INFO ]  Workload [4]
#  68%|██████▊   | 68/100 [01:20<00:31,  1.00it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:14 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:15 AM [pe] [INFO ]  Workload [4]
#  69%|██████▉   | 69/100 [01:21<00:32,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:16 AM [pe] [INFO ]  Workload [4]
#  70%|███████   | 70/100 [01:22<00:31,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:18 AM [pe] [INFO ]  Workload [4]
#  72%|███████▏  | 72/100 [01:24<00:27,  1.02it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:20 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:20 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:23 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:23 AM [pe] [INFO ]  Workload [4]
#  73%|███████▎  | 73/100 [01:29<00:47,  1.78s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:24 AM [pe] [INFO ]  Workload [4]
#  77%|███████▋  | 77/100 [01:29<00:20,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:24 AM [pe] [INFO ]  Workload [4]
#  78%|███████▊  | 78/100 [01:30<00:17,  1.24it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:26 AM [pe] [INFO ]  Workload [4]
#  79%|███████▉  | 79/100 [01:31<00:20,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:28 AM [pe] [INFO ]  Workload [4]
#  80%|████████  | 80/100 [01:34<00:26,  1.30s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:29 AM [pe] [INFO ]  Workload [4]
#  81%|████████  | 81/100 [01:34<00:19,  1.05s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:29 AM [pe] [INFO ]  Workload [4]
#  83%|████████▎ | 83/100 [01:35<00:13,  1.29it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:31 AM [pe] [INFO ]  Workload [4]
#  84%|████████▍ | 84/100 [01:36<00:14,  1.07it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:31 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:34 AM [pe] [INFO ]  Workload [4]
#  85%|████████▌ | 85/100 [01:40<00:22,  1.48s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:35 AM [pe] [INFO ]  Workload [4]
#  88%|████████▊ | 88/100 [01:41<00:10,  1.09it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:38 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:51:38 AM [pe] [INFO ]  Workload [4]
#  89%|████████▉ | 89/100 [01:44<00:15,  1.38s/it]INFO:pe:Workload [4]
# 04/16/2025 01:51:39 AM [pe] [INFO ]  Workload [4]
#  92%|█████████▏| 92/100 [01:44<00:06,  1.28it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:40 AM [pe] [INFO ]  Workload [4]
#  93%|█████████▎| 93/100 [01:46<00:06,  1.06it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:41 AM [pe] [INFO ]  Workload [4]
#  94%|█████████▍| 94/100 [01:46<00:04,  1.23it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:41 AM [pe] [INFO ]  Workload [4]
#  95%|█████████▌| 95/100 [01:47<00:03,  1.44it/s]INFO:pe:Workload [4]
# 04/16/2025 01:51:44 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]
# 04/16/2025 01:51:47 AM [pe] [INFO ]  VARIATION API: constructing data
# INFO:pe:VARIATION API: constructing data
# 04/16/2025 01:51:47 AM [pe] [INFO ]  VARIATION API: finished creating variations for 100 samples
# INFO:pe:VARIATION API: finished creating variations for 100 samples
# 04/16/2025 01:51:47 AM [pe] [INFO ]  Population: finished generating 100*4 initial synthetic samples for label
# INFO:pe:Population: finished generating 100*4 initial synthetic samples for label
# 04/16/2025 01:51:47 AM [pe] [INFO ]  Saving the synthetic text to a CSV file
# INFO:pe:Saving the synthetic text to a CSV file
# 04/16/2025 01:51:47 AM [pe] [INFO ]  Finished saving the synthetic text to a CSV file
# INFO:pe:Finished saving the synthetic text to a CSV file
# 04/16/2025 01:51:47 AM [pe] [INFO ]  Computing FID (PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2, {'PE.VARIATION_API_FOLD_ID':-1})
# INFO:pe:Computing FID (PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2, {'PE.VARIATION_API_FOLD_ID':-1})
# 04/16/2025 01:51:47 AM [pe] [INFO ]  Number of samples after filtering: 100
# INFO:pe:Number of samples after filtering: 100
# 04/16/2025 01:51:47 AM [pe] [INFO ]  Embedding: computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 100/100 samples
# INFO:pe:Embedding: computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 100/100 samples
# 04/16/2025 01:51:48 AM [pe] [INFO ]  Embedding: finished computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 100/100 samples
# INFO:pe:Embedding: finished computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 100/100 samples
# 04/16/2025 01:51:49 AM [pe] [INFO ]  Finished computing FID (PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2, {'PE.VARIATION_API_FOLD_ID':-1})
# INFO:pe:Finished computing FID (PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2, {'PE.VARIATION_API_FOLD_ID':-1})
# 04/16/2025 01:51:49 AM [pe] [INFO ]  Iteration: 0
# INFO:pe:Iteration: 0
# 04/16/2025 01:51:49 AM [pe] [INFO ]  	fid_PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2_{'PE.VARIATION_API_FOLD_ID':-1}: 197.00976001
# INFO:pe:	fid_PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2_{'PE.VARIATION_API_FOLD_ID':-1}: 197.00976001
# 04/16/2025 01:51:49 AM [pe] [INFO ]  PE iteration 1
# INFO:pe:PE iteration 1
# 04/16/2025 01:51:49 AM [pe] [WARNI]  fraction_per_label_id is not provided. Assuming the fraction of label ids in private data is public information.
# WARNING:pe:fraction_per_label_id is not provided. Assuming the fraction of label ids in private data is public information.
# 04/16/2025 01:51:49 AM [pe] [INFO ]  Label 0
# INFO:pe:Label 0
# 04/16/2025 01:51:49 AM [pe] [INFO ]  Histogram: computing nearest neighbors histogram for 10000 private samples and 400 synthetic samples
# INFO:pe:Histogram: computing nearest neighbors histogram for 10000 private samples and 400 synthetic samples
# 04/16/2025 01:51:49 AM [pe] [INFO ]  Embedding: PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 already computed
# INFO:pe:Embedding: PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 already computed
# 04/16/2025 01:51:49 AM [pe] [INFO ]  Embedding: computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 400/400 samples
# INFO:pe:Embedding: computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 400/400 samples
# 04/16/2025 01:51:51 AM [pe] [INFO ]  Embedding: finished computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 400/400 samples
# INFO:pe:Embedding: finished computing PE.EMBEDDING.SentenceTransformer.stsb-roberta-base-v2 for 400/400 samples
# 04/16/2025 01:51:51 AM [pe] [INFO ]  Using faiss backend for nearest neighbor search
# INFO:pe:Using faiss backend for nearest neighbor search
# 04/16/2025 01:51:51 AM [pe] [ERROR]  Error using faiss backend for nearest neighbor search: No module named 'faiss'
# ERROR:pe:Error using faiss backend for nearest neighbor search: No module named 'faiss'
# 04/16/2025 01:51:51 AM [pe] [ERROR]  Traceback (most recent call last):
#   File "/Users/yawetse/Developer/github/yawetse/private-ml/.venv/lib/python3.13/site-packages/pe/histogram/nearest_neighbor_backend/auto.py", line 24, in search
#     from pe.histogram.nearest_neighbor_backend.faiss import search
#   File "/Users/yawetse/Developer/github/yawetse/private-ml/.venv/lib/python3.13/site-packages/pe/histogram/nearest_neighbor_backend/faiss.py", line 1, in <module>
#     import faiss
# ModuleNotFoundError: No module named 'faiss'
#
# ERROR:pe:Traceback (most recent call last):
#   File "/Users/yawetse/Developer/github/yawetse/private-ml/.venv/lib/python3.13/site-packages/pe/histogram/nearest_neighbor_backend/auto.py", line 24, in search
#     from pe.histogram.nearest_neighbor_backend.faiss import search
#   File "/Users/yawetse/Developer/github/yawetse/private-ml/.venv/lib/python3.13/site-packages/pe/histogram/nearest_neighbor_backend/faiss.py", line 1, in <module>
#     import faiss
# ModuleNotFoundError: No module named 'faiss'
#
# 04/16/2025 01:51:51 AM [pe] [INFO ]  Please check the installation of the Faiss library: https://microsoft.github.io/DPSDA/getting_started/installation.html#faiss
# INFO:pe:Please check the installation of the Faiss library: https://microsoft.github.io/DPSDA/getting_started/installation.html#faiss
# 04/16/2025 01:51:51 AM [pe] [INFO ]  Using sklearn backend for nearest neighbor search
# INFO:pe:Using sklearn backend for nearest neighbor search
# ...
# 04/16/2025 01:57:16 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:18 AM [pe] [INFO ]  Workload [4]
#   2%|▏         | 2/100 [00:05<04:12,  2.58s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:20 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:21 AM [pe] [INFO ]  Workload [4]
#   5%|▌         | 5/100 [00:07<01:59,  1.26s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:21 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:21 AM [pe] [INFO ]  Workload [4]
#   7%|▋         | 7/100 [00:08<01:27,  1.07it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:23 AM [pe] [INFO ]  Workload [4]
#   9%|▉         | 9/100 [00:09<01:22,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:24 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:26 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:26 AM [pe] [INFO ]  Workload [4]
#  10%|█         | 10/100 [00:12<01:51,  1.24s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:28 AM [pe] [INFO ]  Workload [4]
#  13%|█▎        | 13/100 [00:14<01:31,  1.05s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:28 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:31 AM [pe] [INFO ]  Workload [4]
#  17%|█▋        | 17/100 [00:17<01:15,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:32 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:34 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:35 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:35 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:35 AM [pe] [INFO ]  Workload [4]
#  19%|█▉        | 19/100 [00:21<01:34,  1.17s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:37 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:38 AM [pe] [INFO ]  Workload [4]
#  25%|██▌       | 25/100 [00:24<00:59,  1.27it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:39 AM [pe] [INFO ]  Workload [4]
#  28%|██▊       | 28/100 [00:25<00:47,  1.51it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:40 AM [pe] [INFO ]  Workload [4]
#  29%|██▉       | 29/100 [00:26<00:49,  1.42it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:41 AM [pe] [INFO ]  Workload [4]
#  30%|███       | 30/100 [00:27<00:51,  1.35it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:42 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:42 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:43 AM [pe] [INFO ]  Workload [4]
#  31%|███       | 31/100 [00:29<01:04,  1.06it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:44 AM [pe] [INFO ]  Workload [4]
#  34%|███▍      | 34/100 [00:30<00:49,  1.33it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:46 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:46 AM [pe] [INFO ]  Workload [4]
#  35%|███▌      | 35/100 [00:32<01:01,  1.05it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:47 AM [pe] [INFO ]  Workload [4]
#  37%|███▋      | 37/100 [00:33<00:45,  1.39it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:48 AM [pe] [INFO ]  Workload [4]
#  38%|███▊      | 38/100 [00:34<00:52,  1.18it/s]INFO:pe:Workload [4]
# 04/16/2025 01:57:50 AM [pe] [INFO ]  Workload [4]
#  39%|███▉      | 39/100 [00:37<01:12,  1.19s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:51 AM [pe] [INFO ]  Workload [4]
#  40%|████      | 40/100 [00:38<01:07,  1.12s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:52 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:53 AM [pe] [INFO ]  Workload [4]
#  41%|████      | 41/100 [00:39<01:14,  1.26s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:56 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:56 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:57:58 AM [pe] [INFO ]  Workload [4]
#  43%|████▎     | 43/100 [00:44<01:36,  1.69s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:58 AM [pe] [INFO ]  Workload [4]
#  44%|████▍     | 44/100 [00:44<01:21,  1.45s/it]INFO:pe:Workload [4]
# 04/16/2025 01:57:59 AM [pe] [INFO ]  Workload [4]
#  47%|████▋     | 47/100 [00:45<00:41,  1.26it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:01 AM [pe] [INFO ]  Workload [4]
#  48%|████▊     | 48/100 [00:47<00:53,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:01 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:01 AM [pe] [INFO ]  Workload [4]
#  49%|████▉     | 49/100 [00:48<00:49,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:04 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:05 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:06 AM [pe] [INFO ]  Workload [4]
#  51%|█████     | 51/100 [00:53<01:17,  1.57s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:08 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:08 AM [pe] [INFO ]  Workload [4]
#  54%|█████▍    | 54/100 [00:55<00:52,  1.14s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:08 AM [pe] [INFO ]  Workload [4]
#  56%|█████▌    | 56/100 [00:55<00:36,  1.22it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:09 AM [pe] [INFO ]  Workload [4]
#  57%|█████▋    | 57/100 [00:56<00:35,  1.21it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:11 AM [pe] [INFO ]  Workload [4]
#  58%|█████▊    | 58/100 [00:57<00:38,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:12 AM [pe] [INFO ]  Workload [4]
#  59%|█████▉    | 59/100 [00:58<00:41,  1.01s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:13 AM [pe] [INFO ]  Workload [4]
#  60%|██████    | 60/100 [00:59<00:36,  1.09it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:14 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:15 AM [pe] [INFO ]  Workload [4]
#  62%|██████▏   | 62/100 [01:01<00:41,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:16 AM [pe] [INFO ]  Workload [4]
#  63%|██████▎   | 63/100 [01:02<00:35,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:16 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:16 AM [pe] [INFO ]  Workload [4]
#  66%|██████▌   | 66/100 [01:02<00:17,  1.95it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:17 AM [pe] [INFO ]  Workload [4]
#  67%|██████▋   | 67/100 [01:04<00:23,  1.38it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:20 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:23 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:24 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:24 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:24 AM [pe] [INFO ]  Workload [4]
#  68%|██████▊   | 68/100 [01:11<01:06,  2.07s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:26 AM [pe] [INFO ]  Workload [4]
#  74%|███████▍  | 74/100 [01:13<00:24,  1.08it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:28 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:28 AM [pe] [INFO ]  Workload [4]
#  75%|███████▌  | 75/100 [01:15<00:26,  1.07s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:30 AM [pe] [INFO ]  Workload [4]
#  78%|███████▊  | 78/100 [01:16<00:18,  1.17it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:32 AM [pe] [INFO ]  Workload [4]
#  80%|████████  | 80/100 [01:18<00:18,  1.10it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:34 AM [pe] [INFO ]  Workload [4]
#  82%|████████▏ | 82/100 [01:21<00:18,  1.00s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:35 AM [pe] [INFO ]  Workload [4]
#  83%|████████▎ | 83/100 [01:21<00:16,  1.05it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:36 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:37 AM [pe] [INFO ]  Workload [4]
#  85%|████████▌ | 85/100 [01:23<00:13,  1.11it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:39 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:40 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:40 AM [pe] [INFO ]  Workload [4]
#  87%|████████▋ | 87/100 [01:26<00:14,  1.12s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:40 AM [pe] [INFO ]  Workload [4]
#  89%|████████▉ | 89/100 [01:26<00:08,  1.25it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:42 AM [pe] [INFO ]  Workload [4]
#  91%|█████████ | 91/100 [01:28<00:07,  1.14it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:43 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:44 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:44 AM [pe] [INFO ]  Workload [4]
#  92%|█████████▏| 92/100 [01:30<00:08,  1.08s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:46 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:47 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 100%|██████████| 100/100 [01:37<00:00,  1.02it/s]
# 04/16/2025 01:58:51 AM [pe] [INFO ]  VARIATION API: constructing data
# INFO:pe:VARIATION API: constructing data
# 04/16/2025 01:58:51 AM [pe] [INFO ]  VARIATION API: finished creating variations for 100 samples
# INFO:pe:VARIATION API: finished creating variations for 100 samples
# 04/16/2025 01:58:51 AM [pe] [INFO ]  VARIATION API: creating variations for 100 samples
# INFO:pe:VARIATION API: creating variations for 100 samples
# 04/16/2025 01:58:51 AM [pe] [INFO ]  VARIATION API: producing LLM requests
# INFO:pe:VARIATION API: producing LLM requests
# 04/16/2025 01:58:51 AM [pe] [INFO ]  VARIATION API: getting LLM responses
# INFO:pe:VARIATION API: getting LLM responses
# 04/16/2025 01:58:51 AM [pe] [INFO ]  Workload [1]
# INFO:pe:Workload [1]
# 04/16/2025 01:58:51 AM [pe] [INFO ]  Workload [2]
# INFO:pe:Workload [2]
#   0%|          | 0/100 [00:00<?, ?it/s]04/16/2025 01:58:51 AM [pe] [INFO ]  Workload [3]
# INFO:pe:Workload [3]
# 04/16/2025 01:58:51 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:53 AM [pe] [INFO ]  Workload [4]
#   1%|          | 1/100 [00:01<02:16,  1.38s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:53 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:58:57 AM [pe] [INFO ]  Workload [4]
#   2%|▏         | 2/100 [00:05<05:02,  3.09s/it]INFO:pe:Workload [4]
# 04/16/2025 01:58:57 AM [pe] [INFO ]  Workload [4]
#   5%|▌         | 5/100 [00:05<01:28,  1.08it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:57 AM [pe] [INFO ]  Workload [4]
#   6%|▌         | 6/100 [00:06<01:12,  1.30it/s]INFO:pe:Workload [4]
# 04/16/2025 01:58:58 AM [pe] [INFO ]  Workload [4]
#   7%|▋         | 7/100 [00:06<01:05,  1.42it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:00 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:00 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:01 AM [pe] [INFO ]  Workload [4]
#   8%|▊         | 8/100 [00:09<02:04,  1.35s/it]INFO:pe:Workload [4]
# 04/16/2025 01:59:02 AM [pe] [INFO ]  Workload [4]
#  11%|█         | 11/100 [00:10<01:09,  1.29it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:02 AM [pe] [INFO ]  Workload [4]
#  12%|█▏        | 12/100 [00:11<01:01,  1.44it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:03 AM [pe] [INFO ]  Workload [4]
#  13%|█▎        | 13/100 [00:12<01:07,  1.29it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:04 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:04 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:04 AM [pe] [INFO ]  Workload [4]
#  14%|█▍        | 14/100 [00:13<01:16,  1.12it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:05 AM [pe] [INFO ]  Workload [4]
#  17%|█▋        | 17/100 [00:13<00:41,  2.00it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:08 AM [pe] [INFO ]  Workload [4]
#  18%|█▊        | 18/100 [00:16<01:18,  1.04it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:08 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:08 AM [pe] [INFO ]  Workload [4]
#  19%|█▉        | 19/100 [00:17<01:15,  1.07it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:09 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:10 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:10 AM [pe] [INFO ]  Workload [4]
#  22%|██▏       | 22/100 [00:18<00:56,  1.38it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:12 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:12 AM [pe] [INFO ]  Workload [4]
#  23%|██▎       | 23/100 [00:21<01:20,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:59:13 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:13 AM [pe] [INFO ]  Workload [4]
#  25%|██▌       | 25/100 [00:22<01:02,  1.20it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:15 AM [pe] [INFO ]  Workload [4]
#  28%|██▊       | 28/100 [00:23<00:52,  1.38it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:16 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:16 AM [pe] [INFO ]  Workload [4]
#  29%|██▉       | 29/100 [00:24<00:50,  1.41it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:16 AM [pe] [INFO ]  Workload [4]
#  30%|███       | 30/100 [00:24<00:44,  1.57it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:19 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:19 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:20 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:20 AM [pe] [INFO ]  Workload [4]
#  32%|███▏      | 32/100 [00:28<01:16,  1.12s/it]INFO:pe:Workload [4]
# 04/16/2025 01:59:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:22 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:22 AM [pe] [INFO ]  Workload [4]
#  36%|███▌      | 36/100 [00:31<00:54,  1.18it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:23 AM [pe] [INFO ]  Workload [4]
#  37%|███▋      | 37/100 [00:31<00:52,  1.21it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:25 AM [pe] [INFO ]  Workload [4]
#  40%|████      | 40/100 [00:34<00:47,  1.25it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:27 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:28 AM [pe] [INFO ]  Workload [4]
#  41%|████      | 41/100 [00:36<01:01,  1.04s/it]INFO:pe:Workload [4]
# 04/16/2025 01:59:29 AM [pe] [INFO ]  Workload [4]
#  43%|████▎     | 43/100 [00:37<00:49,  1.16it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:30 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:32 AM [pe] [INFO ]  Workload [4]
#  45%|████▌     | 45/100 [00:40<00:58,  1.06s/it]INFO:pe:Workload [4]
# 04/16/2025 01:59:33 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:34 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:35 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:36 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:38 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:38 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:38 AM [pe] [INFO ]  Workload [4]
#  47%|████▋     | 47/100 [00:46<01:31,  1.73s/it]INFO:pe:Workload [4]
# 04/16/2025 01:59:41 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:41 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:41 AM [pe] [INFO ]  Workload [4]
#  54%|█████▍    | 54/100 [00:50<00:44,  1.03it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:43 AM [pe] [INFO ]  Workload [4]
#  57%|█████▋    | 57/100 [00:51<00:36,  1.17it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:43 AM [pe] [INFO ]  Workload [4]
#  58%|█████▊    | 58/100 [00:52<00:33,  1.27it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:45 AM [pe] [INFO ]  Workload [4]
#  59%|█████▉    | 59/100 [00:53<00:36,  1.13it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:46 AM [pe] [INFO ]  Workload [4]
# INFO:pe:Workload [4]
# 04/16/2025 01:59:46 AM [pe] [INFO ]  Workload [4]
#  60%|██████    | 60/100 [00:54<00:37,  1.06it/s]INFO:pe:Workload [4]
# 04/16/2025 01:59:47 AM [pe] [INFO ]  Workload [4]
#  62%|██████▏   | 62/100 [00:56<00:32,  1.16it/s]INFO:pe:Workload [4]
